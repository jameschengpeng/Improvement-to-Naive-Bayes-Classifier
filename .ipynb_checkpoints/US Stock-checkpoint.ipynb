# %%
import numpy as np
import pandas as pd
import comonotonic as cm
import os
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
import copy
import utils
import matplotlib.pyplot as plt
import seaborn as sns

# %%
year = 2014
filename = "cleaned_" + str(year) + "_Financial_Data.csv"
random_state = 24
df = pd.read_csv("Datasets/US_stock/"+filename)
df.rename(columns={'Unnamed: 0': 'Company'}, inplace = True)
shuffled_df = shuffle(df)

# %%
shuffled_df = shuffled_df.drop(['Company', str(year+1)+' PRICE VAR [%]', 'operatingCycle', 'cashConversionCycle'], axis = 1)
# drop the constant columns if exist 
for col in shuffled_df.columns:
    if len(shuffled_df[col].unique()) == 1:
        shuffled_df.drop(col,inplace=True,axis=1)

# %%
real_colnames = list(shuffled_df.columns.values)
colnames = [('X'+str(i)) for i in range(shuffled_df.shape[1]-1)]
colnames.append('Y')
colname_checker = {colnames[i]:real_colnames[i] for i in range(len(colnames))}
shuffled_df.columns = colnames

# %%
encoded_df = utils.encode_df(shuffled_df, [218])
encoded_df = encoded_df.astype({'X218': 'int32'})
cont_col = [i for i in range(218)]
unrankable = [218]

# %%
test_df = encoded_df.drop(['X218','Y'], axis = 1)
heat_map_X = test_df.to_numpy()
corr = np.corrcoef(heat_map_X.T)
ax = sns.heatmap(corr)

# %%
# replace the extreme values, too small? replace by 5% quantile value; too large? replace by 95% quantile value
inf = encoded_df[colnames[:-2]].quantile(0.05, axis = 0)
sup = encoded_df[colnames[:-2]].quantile(0.95, axis = 0)
for i in range(encoded_df.shape[1]-2):
    col = 'X'+str(i)
    encoded_df[col] = np.where((encoded_df[col] < inf[i]), inf[i], encoded_df[col])
    encoded_df[col] = np.where((encoded_df[col] > sup[i]), sup[i], encoded_df[col])

# %%
# implementation of NB from scratch
nb_X = encoded_df[colnames[:-1]].to_numpy()
nb_Y = encoded_df[colnames[-1]].to_numpy()
nb_X_train, nb_X_test, nb_Y_train, nb_Y_test = train_test_split(nb_X, nb_Y, test_size=0.2, random_state=random_state)

nb_classifier = cm.naive_bayes(nb_X_train, nb_Y_train, cont_col)
nb_classifier.run()
nb_y_predict = nb_classifier.predict(nb_X_test)
utils.get_accuracy(nb_y_predict, nb_Y_test)
# Out:
# 0.6220472440944882

# %%
# clustered comonotonic
df_for_cluster = encoded_df.copy()
unrankable_fv = {218:11}
num_categories_list = [2,3,4,5,6]

#continuous variables; categorical rankable features are [3]
cluster_accuracy_history, cluster_allocation_history = utils.determine_allocation(cont_col, num_categories_list,
                                                               df_for_cluster, unrankable_fv,
                                                               colnames, max_itr = 5, temp = 2,
                                                               anneal_schedule = 10, use_cluster = True,
                                                               use_mistaken_accuracy_test = False, 
                                                               random_state = random_state, min_corr = 0.7)
# Out:
# /Users/pengcheng/opt/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py:2534: RuntimeWarning: divide by zero encountered in true_divide
#   c /= stddev[:, None]
# /Users/pengcheng/opt/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py:2534: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# /Users/pengcheng/opt/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py:2535: RuntimeWarning: divide by zero encountered in true_divide
#   c /= stddev[None, :]
# /Users/pengcheng/opt/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py:2535: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]

# %%
plt.plot(list(cluster_accuracy_history.values()))

# %%
cluster_accuracy_history_record = list(cluster_accuracy_history.values())
opt_allocation = cluster_allocation_history[cluster_accuracy_history_record.index(max(cluster_accuracy_history_record))]

# %%
# clustered comonotonic validation
como_cluster_df = encoded_df.copy()
uncategorized_df = encoded_df.copy()
feature_val = utils.merge_dict(unrankable_fv, opt_allocation)
for col in range(como_cluster_df.shape[1]-1):
    if col not in feature_val.keys():
        feature_val[col] = df['X'+str(col)].nunique()
        
for col_idx in opt_allocation.keys():
    discretized_col = pd.cut(como_cluster_df.iloc[:,col_idx],opt_allocation[col_idx], labels=[i for i in range(opt_allocation[col_idx])])
    como_cluster_df['X'+str(col_idx)] = discretized_col
X_cluster = como_cluster_df[colnames[:-1]].to_numpy()
Y_cluster = como_cluster_df[colnames[-1]].to_numpy()
X_train_cluster, X_test_cluster, Y_train_cluster, Y_test_cluster = train_test_split(X_cluster, Y_cluster, 
                                                                                    test_size=0.2, random_state=random_state)

como_cluster_classifier = cm.clustered_comonotonic(X_train_cluster, Y_train_cluster, unrankable, feature_val, uncategorized_df, 
                                                   colnames, min_corr = 0.6, random_state = random_state)
como_cluster_classifier.run_cluster()
Y_cluster_pred = como_cluster_classifier.predict(X_test_cluster)
utils.get_accuracy(Y_cluster_pred, Y_test_cluster)
# Out:
# 0.5971128608923885

# %%
# weighted average of naive bayes and cluster comonotonic
weighted_predict_y = []
for i in range(len(X_test_cluster)):
    prob_dist_cluster_como = como_cluster_classifier.get_prob_dist_single(X_test_cluster[i])
    predicted_class, prob_dist_nb = nb_classifier.predict_single(nb_X_test[i])
    weighted_predict_y.append(utils.weighted_avg(prob_dist_nb, prob_dist_cluster_como, 0.6))

print(utils.get_accuracy(weighted_predict_y, Y_test_cluster))
# Out:
# 0.5406824146981627
